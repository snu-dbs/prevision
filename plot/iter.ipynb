# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('classic')

plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams["font.size"] = "14"

# x = ['100', '200', '400', '800', '1600', '3200']
# x = ['100\n(640MB)', '200\n(320MB)', '400\n(160MB)', '800\n(80MB)', '1600\n(40MB)', '3200\n(20MB)']

label = ['TilePACK', 'SystemDS', 'NumPy', 'Dask', 'SciDB', 'MADlib', 'MLlib']
x = [1, 2, 4, 8, 16, 32]

fig = plt.figure(figsize=(5, 2.5))

plt.plot(x, np.array([39, 51, 74, 120, 210, 395]), marker='s', color='r')                  # SystemDS
plt.plot(x, np.array([72, 125, 231, 444, 872, 1732]), marker='^', color='c')               # NumPy
plt.plot(x, np.array([58, 91, 160, 293, 560, 1100]), marker='d', color='k')                # Dask
plt.plot(x, np.array([202, 402, 805, 1607, 3209, 6416]), marker='*', color='g')            # SciDB
plt.plot(x, np.array([1517, 2966, 5892, 11685, 23381, 58212]), marker='P', color='m')      # MADlib
plt.plot(x, np.array([357, 446, 656, 1062, 1814, 3408]), marker='o', color='y')            # MLlib
plt.plot(x, np.array([30, 38, 52, 81, 139, 254]), marker='X', color='b')                   # TilePACK

# plt.legend(['Overhead', 'Total', 'Second Best Performer (NumPy)'])

plt.xlim(1, 32)
# plt.ylim(1, 32)
plt.yscale('log')
plt.tick_params(axis='both', which='major', labelsize=13)
plt.ylabel("Elapsed time (s)", fontdict={'size': 13})

plt.xlabel("The number of iterations", fontdict={'size': 13}, labelpad=12)

# plt.legend(label)
fig.patch.set_facecolor('white')

plt.grid()

plt.savefig('iter_nmf10.pdf', format='pdf', bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('classic')

plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams["font.size"] = "14"
plt.rcParams['image.cmap'] = 'tab10'

# x = ['100', '200', '400', '800', '1600', '3200']
# x = ['100\n(640MB)', '200\n(320MB)', '400\n(160MB)', '800\n(80MB)', '1600\n(40MB)', '3200\n(20MB)']

label = ['TilePACK', 'MLlib', 'SciDB']
x = [1, 2, 4, 8, 16, 32]
# time = np.array([
#     ,          # TilePACK
#     , # MLlib
#     , # SciDB
# ]) / 1000

fig = plt.figure(figsize=(5, 2.5))

# plt.plot(x, time.T, marker='x')

# MADlib
plt.plot([1, 2, 4, 8], np.array([6045119, 9663272, 14397882, 26473403,]) / 1000, marker='P', color='m')

# plt.plot(x, np.array([39, 51, 74, 120, 210, 395]), marker='s', color='r')                  # SystemDS
plt.plot(x, np.array([568.626, 1124.186, 2259.482, 4515.786, 9074.289, 18102.633]), marker='*', color='g')            # SciDB
# plt.plot(x, np.array([1.517, 2.966, 5.892, 11.685, 23.381, 58.212]), marker='d', color='k')      # MADlib
plt.plot(x, np.array([2270.623, 2410.800, 2822.666, 3333.150, 4396.515, 6535.390]), marker='o', color='y')            # MLlib
plt.plot(x, np.array([64.755, 81.570, 97.920, 130.901, 196.928, 327.178]), marker='X', color='b')                   # TilePACK

# plt.legend(['Overhead', 'Total', 'Second Best Performer (NumPy)'])

plt.xlim(1, 32)
# plt.ylim(1, 32)
plt.yscale('log')
plt.tick_params(axis='both', which='major', labelsize=13)
plt.ylabel("Elapsed time (s)", fontdict={'size': 13})

plt.xlabel("The number of iterations", fontdict={'size': 13}, labelpad=12)

# plt.legend(label)
fig.patch.set_facecolor('white')

plt.grid()

plt.savefig('iter_prtwitter.pdf', format='pdf', bbox_inches='tight')

# %%
# for legend
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('classic')

plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams["font.size"] = "14"

# x = ['100', '200', '400', '800', '1600', '3200']
# x = ['100\n(640MB)', '200\n(320MB)', '400\n(160MB)', '800\n(80MB)', '1600\n(40MB)', '3200\n(20MB)']

label = ['TilePACK', 'SystemDS', 'NumPy', 'Dask', 'SciDB', 'MADlib', 'MLlib']
x = [1, 2, 4, 8, 16, 32]

fig = plt.figure(figsize=(4, 2))
ax = fig.add_axes([0, 0, 1, 1])

plt.plot(x, np.array([30, 38, 52, 81, 139, 254]), marker='X', color='b', label='PreVision')                   # TilePACK
plt.plot(x, np.array([39, 51, 74, 120, 210, 395]), marker='s', color='r', label='SystemDS')                  # SystemDS
plt.plot(x, np.array([72, 125, 231, 444, 872, 1732]), marker='^', color='c', label='NumPy')               # NumPy
plt.plot(x, np.array([58, 91, 160, 293, 560, 1100]), marker='d', color='k', label='Dask')                # Dask
plt.plot(x, np.array([183, 402, 805, 1607, 3209, 6416]), marker='*', color='g', label='SciDB')            # SciDB
plt.plot(x, np.array([1517, 2966, 5892, 11685, 23381, 58212]), marker='P', color='m', label='MADlib')      # MADlib
plt.plot(x, np.array([357, 446, 656, 1062, 1814, 3408]), marker='o', color='y', label='MLlib')            # MLlib

# plt.legend(['Overhead', 'Total', 'Second Best Performer (NumPy)'])

# ax.xlim(1, 32)
# plt.ylim(1, 32)
# ax.yscale('log')
ax.tick_params(axis='both', which='major', labelsize=17)
# ax.ylabel("Elapsed time (s)", fontdict={'size': 17})

# ax.xlabel("The number of iterations", fontdict={'size': 17}, labelpad=12)

# plt.legend(label)
# fig.patch.set_facecolor('white')

ax.grid()

plt.savefig('iter_nmf2210.pdf', format='pdf', bbox_inches='tight')

lfig = plt.figure(figsize=(4.5, 2.2))

from matplotlib.lines import Line2D

legend_elements = [Line2D([0], [0], color='r', marker='s', label='SystemDS'),]
                #    Line2D([0], [0], marker='o', color='w', label='Scatter',
                #           markerfacecolor='g', markersize=15),
                #    Patch(facecolor='orange', edgecolor='r',
                #          label='Color Patch')]

# plt.figlegend(handles=legend_elements, loc = 'upper center', ncol=5, mode="expand", fontsize=11)
plt.figlegend(*ax.get_legend_handles_labels(), loc = 'upper center', ncol=4, mode="expand", fontsize=11, numpoints=1)
lfig.savefig('iter_legend.pdf', format='pdf', bbox_inches='tight')
