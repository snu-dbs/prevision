# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams["font.size"] = "14"

x = ['100', '200', '400', '800', '1600', '3200']
# x = ['100\n(640MB)', '200\n(320MB)', '400\n(160MB)', '800\n(80MB)', '1600\n(40MB)', '3200\n(20MB)']

total = np.array([265439987, 267635648, 283293168, 312722397, 329868764, 350022933]) / 1000000
overhead = np.array([26594, 64297, 213908, 907918, 3394511, 13663793]) / 1000000

second = np.array([779710000 for _ in range(6)]) / 1000000

plt.figure(figsize=(4, 2))

plt.fill_between(x, 0, overhead, color='gray', edgecolor='black')
plt.fill_between(x, overhead, total, color='lightgray', edgecolor='gray')
plt.plot(x, second, color='black')

plt.plot(x, overhead, color='black')
plt.plot(x, total, color='gray', marker='x')

plt.xlim(0, 5)
plt.ylim(0, 1000)
plt.tick_params(axis='both', which='major', labelsize=11)
plt.ylabel("Elapsed time (s)", fontdict={'size': 12})

plt.xlabel("The number of tiles (tile size)", fontdict={'size': 11}, labelpad=12)

plt.text(3.8, 830, "NumPy", {'size': 10, 'weight': 'bold'})

plt.text(-0.3, -210, "(640MB)", {'size': 8})
plt.text(0.66, -210, "(320MB)", {'size': 8})
plt.text(1.66, -210, "(160MB)", {'size': 8})
plt.text(2.73, -210, "(80MB)", {'size': 8})
plt.text(3.72, -210, "(40MB)", {'size': 8})
plt.text(4.72, -210, "(20MB)", {'size': 8})

plt.grid()

plt.legend(['Overhead', 'Total'], prop={'size': 8}, loc='upper left')

plt.savefig('smalltile_lr.pdf', format='pdf', bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams["font.size"] = "14"

x = ['', '200', ' ', '800', '  ', '3200']
# x = ['100\n(640MB)', '200\n(320MB)', '400\n(160MB)', '800\n(80MB)', '1600\n(40MB)', '3200\n(20MB)']

total = np.array([265439987, 267635648, 283293168, 312722397, 329868764, 350022933]) / 1000000
overhead = np.array([26594, 64297, 213908, 907918, 3394511, 13663793]) / 1000000

second = np.array([779710000 for _ in range(6)]) / 1000000

plt.figure(figsize=(4, 2.5))

plt.fill_between(x, 0, overhead, color='gray', edgecolor='black')
plt.fill_between(x, overhead, total, color='lightgray', edgecolor='gray')
plt.plot(x, second, color='black')

plt.plot(x, overhead, color='black')
plt.plot(x, total, color='gray', marker='x')

plt.xlim(0, 5)
plt.ylim(0, 1050)
plt.tick_params(axis='both', which='major', labelsize=20)
plt.ylabel("Elapsed time (s)", fontdict={'size': 20})

plt.xlabel("The number of tiles (tile size)", fontdict={'size': 20}, labelpad=20)

plt.text(3.5, 840, "NumPy", {'size': 20, 'weight': 'bold'})

# plt.text(-0.52, -250, "(640MB)", {'size': 13})
plt.text(0.34, -280, "(320MB)", {'size': 17})
# plt.text(1.54, -250, "(160MB)", {'size': 13})
plt.text(2.4, -280, "(80MB)", {'size': 17})
# plt.text(3.60, -250, "(40MB)", {'size': 13})
plt.text(4.4, -280, "(20MB)", {'size': 17})

plt.yticks([250, 500, 750, 1000])
plt.grid()

plt.legend(['Overhead', 'Total'], prop={'size': 16}, loc='upper left')

plt.savefig('smalltile_lr.pdf', format='pdf', bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams["font.size"] = "14"

x = ['100', '200', '400', '800', '1600', '3200']
# x = ['100\n(640MB)', '200\n(320MB)', '400\n(160MB)', '800\n(80MB)', '1600\n(40MB)', '3200\n(20MB)']

# total = np.array([492482559, 491031164, 527596965, 567706772, 590086841, 605543981]) / 1000000
# overhead = np.array([74980, 154675, 491612, 1741914, 7230138, 32277340]) / 1000000

# second = np.array([2581130000 for _ in range(6)]) / 1000000

total = np.array([497009581, 494458933, 531167740, 571411875, 602693258, 643867140]) / 1000000
overhead = np.array([61080, 162726, 538084, 2027090, 7804991, 32119646]) / 1000000

second = np.array([2581, 2529, 2720, 2792, 3236, 4133])

plt.figure(figsize=(4, 2))

plt.fill_between(x, 0, overhead, color='gray', edgecolor='black')
plt.fill_between(x, overhead, total, color='lightgray', edgecolor='gray')
plt.plot(x, second, color='black', marker='+')

plt.plot(x, overhead, color='black')
plt.plot(x, total, color='gray', marker='x')

# plt.legend(['Overhead', 'Total', 'Second Best Performer (NumPy)'])

plt.xlim(0, 5)
plt.ylim(0, 4500)
plt.tick_params(axis='both', which='major', labelsize=11)
plt.ylabel("Elapsed time (s)", fontdict={'size': 12})

plt.xlabel("The number of tiles (tile size)", fontdict={'size': 11}, labelpad=12)

plt.text(3.02, 3200, "Dask", {'size': 10, 'weight': 'bold'})

plt.text(-0.3, -900, "(640MB)", {'size': 8})
plt.text(0.66, -900, "(320MB)", {'size': 8})
plt.text(1.66, -900, "(160MB)", {'size': 8})
plt.text(2.73, -900, "(80MB)", {'size': 8})
plt.text(3.72, -900, "(40MB)", {'size': 8})
plt.text(4.72, -900, "(20MB)", {'size': 8})

plt.legend(['Overhead', 'Total'], prop={'size': 8}, loc='upper left')

plt.grid()

plt.savefig('smalltile_nmf.pdf', format='pdf', bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams["font.size"] = "14"

x = ['', '200', ' ', '800', '  ', '3200']
# x = ['100\n(640MB)', '200\n(320MB)', '400\n(160MB)', '800\n(80MB)', '1600\n(40MB)', '3200\n(20MB)']

total = np.array([497009581, 494458933, 531167740, 571411875, 602693258, 643867140]) / 1000000
overhead = np.array([61080, 162726, 538084, 2027090, 7804991, 32119646]) / 1000000

second = np.array([2581, 2529, 2720, 2792, 3236, 4133])

fig = plt.figure(figsize=(4, 2.5))
# plt = fig.add_axes([0, 0, 1, 1])

plt.fill_between(x, 0, overhead, color='gray', edgecolor='black')
plt.fill_between(x, overhead, total, color='lightgray', edgecolor='gray')
plt.plot(x, second, color='black', marker='+')
plt.plot(x, overhead, color='black')
plt.plot(x, total, color='gray', marker='x')

plt.plot(x, overhead, color='black')
plt.plot(x, total, color='gray', marker='x')

plt.xlim(0, 5)
plt.ylim(0, 4500)
plt.tick_params(axis='both', which='major', labelsize=20)
# plt.ylabel("Elapsed time (s)", fontdict={'size': 20})

plt.xlabel("The number of tiles (tile size)", fontdict={'size': 20}, labelpad=20)

plt.text(2.8, 3340, "Dask", {'size': 20, 'weight': 'bold'})

# plt.text(-0.52, -250, "(640MB)", {'size': 13})
plt.text(0.34, -1220, "(320MB)", {'size': 17})
# plt.text(1.54, -250, "(160MB)", {'size': 13})
plt.text(2.4, -1220, "(80MB)", {'size': 17})
# plt.text(3.60, -250, "(40MB)", {'size': 13})
plt.text(4.4, -1220, "(20MB)", {'size': 17})

plt.yticks([1000, 2000, 3000, 4000])
plt.grid()

# plt.legend(['Overhead', 'Total'], prop={'size': 14}, loc='upper left')

plt.savefig('smalltile_nmf.pdf', format='pdf', bbox_inches='tight')
 
# print((first, second2))
# lfig = plt.figure()
# plt.figlegend(*ax.get_legend_handles_labels(), loc = 'upper center', ncol=5, mode="expand", fontsize=11)
# lfig.savefig('smalltile_legend.pdf', format='pdf', bbox_inches='tight')
